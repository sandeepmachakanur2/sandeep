# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepmachakanur2/sandeep/blob/main/week_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# !pip install pandas
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import LinearRegression
df = pd.read_csv("/content/train (1).csv")
df.head()
# Out:
# ...
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
target = df["Loan_ID"]

# %%
train = df.drop("Loan_ID", axis=1)
train.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(train, target, test_size=0.20)
model_1 = LinearRegression()
model_2 = xgb.XGBRegressor()
model_3 = RandomForestRegressor()
model_1.fit(X_train, y_train)
model_2.fit(X_train, y_train)
model_3.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-a32e41141e5b> in <cell line: 5>()
#       3 model_2 = xgb.XGBRegressor()
#       4 model_3 = RandomForestRegressor()
# ----> 5 model_1.fit(X_train, y_train)
#       6 model_2.fit(X_train, y_train)
#       7 model_3.fit(X_train, y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     676         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     677
# --> 678         X, y = self._validate_data(
# ...

# %%
# This code needs to be run before calculating pred_final
pred_1 = model_1.predict(X_test)
pred_2 = model_2.predict(X_test)
pred_3 = model_3.predict(X_test)

pred_final = (pred_1+pred_2+pred_3)/3.0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-4a0f5a32ffac> in <cell line: 2>()
#       1 # This code needs to be run before calculating pred_final
# ----> 2 pred_1 = model_1.predict(X_test)
#       3 pred_2 = model_2.predict(X_test)
#       4 pred_3 = model_3.predict(X_test)
#       5
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in predict(self, X)
#     384             Returns predicted values.
#     385         """
# --> 386         return self._decision_function(X)
#     387
#     388     def _set_intercept(self, X_offset, y_offset, X_scale):
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     367         check_is_fitted(self)
#     368
# --> 369         X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
# ...

# %%
'pred_1' in globals()
'pred_2' in globals()
'pred_3' in globals()
# Out:
# False

# %%
print(mean_squared_error(y_test, pred_final))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-8b2ec954c968> in <cell line: 1>()
# ----> 1 print(mean_squared_error(y_test, pred_final))
#
# NameError: name 'pred_final' is not defined

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss

# %%
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.ensemble import VotingClassifier
df = pd.read_csv("/content/train (1).csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...
